# %% [markdown]
# ## Insurance Claim Fraud Detection

# %% [markdown]
# Project Description
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.
#
# Independent Variables
# 1.	months_as_customer: Number of months of patronage
# 2.	age: the length of time a customer has lived or a thing has existed
# 3.	policy_number: It is a unique id given to the customer, to track the subscription status and other details of customer
# 4.	policy_bind_date:date which document that is given to customer after we accept your proposal for insurance
# 5.	policy_state: This identifies who is the insured, what risks or property are covered, the policy limits, and the policy period
# 6.	policy_csl: is basically Combined Single Limit
# 7.	policy_deductable: the amount of money that a customer is responsible for paying toward an insured loss
# 8.	policy_annual_premium: This means the amount of Regular Premium payable by the Policyholder in a Policy Year
# 9.	umbrella_limit: This means extra insurance that provides protection beyond existing limits and coverages of other policies
# 10.	insured_zip: It is the zip code where the insurance was made
# 11.	insured_sex: This refres to either of the two main categories (male and female) into which customer are divided on the basis of their reproductive functions
# 12.	insured_education_level: This refers to the Level of education of the customer
# 13.	insured_occupation: This refers Occupation of the customer
# 14.	insured_hobbies: This refers to an activity done regularly by customer in his/her leisure time for pleasure.
# 15.	insured_relationship: This whether customer is: single; or. married; or. in a de facto relationship (that is, living together but not married); or. in a civil partnership
# 16.	capital-gains: This refers to profit accrued due to insurance premium
# 17.	capital-loss: This refers to the losses incurred due to insurance claims
# 18.	incident_date: This refers to the date which claims where made by customers
# 19.	incident_type: This refers to the type of claim/vehicle damage made by customer
# 20.	collision_type: This refers to the area of damage on the vehicle
# 21.	incident_severity: This refers to the extent/level of damage
# 22.	authorities_contacted: This refers to the government agencies that were contacted after damage
# 23.	incident_state: This refers to the state at which the accident happened
# 24.	incident_city: This refers to the city at which the accident happened
# 25.	1ncident_location: This refers to the location at which the accident happened
# 26.	incident_hour_of_the_day: The period of the day which accident took place
# 27.	number_of_vehicles_involved: This refers to number of vehicles involved the accident
# 28.	property_damage: This refers to whether property was damaged or not
# 29.	bodily_injuries: This refers to injuries sustained
# 30.	witnesses: This refers to the number of witnesses involved
# 31.	police_report_available: This refers to whether the report on damage was documented or not
# 32.	total_claim_amount: This refers to the financial implications involved in claims
# 33.	injury_claim: This refers to physical injuries sustained
# 34.	property_claim: This refers to property damages during incident
# 35.	vehicle_claim: This refers to property damages during incident
# 36.	auto_make: This refers to the make of the vehicle
# 37.	auto_model: This refers to the model of the vehicle
# 38.	auto_year: This refers to the year which the vehicle was manufactured
# 39.	_c39:
# 40.	fraud_reported

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the Data Set

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.sample(15)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 346                 429   56         804410       12-12-1998           OH
# 272                 332   47         994538       01-11-1991           IL
# 696                 176   36         641845       30-03-1995           OH
# 206                 128   32         547744       08-07-2001           OH
# 874                 228   39         762951       19-09-2012           IN
# 40                   79   26         206213       08-05-1995           IL
# 913                 259   45         608443       21-12-2006           IL
# 592                 253   41         228403       20-04-2004           IN
# 144                 106   31         165485       12-02-1998           IL
# 491                   4   39         498759       05-09-1996           IL
# 658                 303   43         674485       14-01-1999           OH
# 691                 199   38         206004       26-09-1991           IL
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
#Sorting the columns according to dtypes.
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year'], float64: ['policy_annual_premium', '_c39'], object: ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']}

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# Checking the duplicate on the basis of policy no.

df.duplicated('policy_number').sum()
# Out:
# 0

# %%
# Checking if any special characters are there in any columns.

df.isin(['  ', 'NA', '-']).sum().any()
# Out:
# False

# %% [markdown]
# We can see ? values in columns. we will check it and replace it with Nan.

# %%
df.isin(['?']).sum().any()
# Out:
# True

# %%
df=df.replace('?',np.NaN)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# Checking the Nan values in the columns.

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# We can see 3 colums are having sum NaN values and colum _c39 is having all the values NaN. We will be dropping that column.

# %%
df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %%
# Droping unnecessary columns
df.drop(['_c39','incident_location','insured_zip','policy_number'],axis=1,inplace=True)

# %% [markdown]
# Checking missing values after filling missing values.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# ...

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       17-10-2014           OH    250/500
# 1                   228   42       27-06-2006           IN    250/500
# 2                   134   29       06-09-2000           OH    100/300
# 3                   256   41       25-05-1990           IL    250/500
# 4                   228   44       06-06-2014           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       16-07-1991           OH   500/1000
# 996                 285   41       05-01-2014           IL    100/300
# 997                 130   34       17-02-2003           OH    250/500
# 998                 458   62       18-11-2011           IL   500/1000
# 999                 456   60       11-11-1996           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_bind_date             1000 non-null   object
#  3   policy_state                 1000 non-null   object
#  4   policy_csl                   1000 non-null   object
#  5   policy_deductable            1000 non-null   int64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_sex                  1000 non-null   object
#  9   insured_education_level      1000 non-null   object
#  10  insured_occupation           1000 non-null   object
#  11  insured_hobbies              1000 non-null   object
#  12  insured_relationship         1000 non-null   object
# ...

# %% [markdown]
# Observations:
#
# 1) Now we can see that there are total 35 columns which means there are 35 different attributes in set.
#
# 2) There are 1000 rows which means there 1000 instances of our attributes.
#
# 3) There are 34 independent attributes and 1 target attributes, which is fraud reported or not.
#
# 4) Three types of data types can be seen - float (1 column), integer(15 columns), string (20 columns).
#
# 5) We have filled the NaN values of the columns & removed unneccessary columns from set.

# %%
# Converting Date columns from object type into datetime data type
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
# Extracting Day, Month and Year column from policy_bind_date
df['policy_bind_day'] = df['policy_bind_date'].dt.day
df['policy_bind_month'] = df['policy_bind_date'].dt.month
df['policy_bind_year'] = df['policy_bind_date'].dt.year

# Extracting Day, Month and Year column from incident_date
df['incident_day'] = df['incident_date'].dt.day
df['incident_month'] = df['incident_date'].dt.month
df['incident_year'] = df['incident_date'].dt.year

# %%
df.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)
df.drop(['incident_year'],axis=1,inplace=True)

# %%
df
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_sex', 'insured_education_level', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported', 'policy_bind_day', 'policy_bind_month',
#        'policy_bind_year', 'incident_day', 'incident_month'],
#       dtype='object')

# %% [markdown]
# Splitting numerical & categorical columns

# %%
num_col = df.select_dtypes(['int', 'float'])
cat_col = df.select_dtypes(['object'])

# %%
num_col
# Out:
#      months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                   328   48               1000                1406.91
# 1                   228   42               2000                1197.22
# 2                   134   29               2000                1413.14
# 3                   256   41               2000                1415.74
# 4                   228   44               1000                1583.91
# ..                  ...  ...                ...                    ...
# 995                   3   38               1000                1310.80
# 996                 285   41               1000                1436.79
# 997                 130   34                500                1383.49
# 998                 458   62               2000                1356.92
# 999                 456   60               1000                 766.19
#
#      umbrella_limit  capital-gains  capital-loss  incident_hour_of_the_day  \
# ...

# %%
cat_col
# Out:
#     policy_state policy_csl insured_sex insured_education_level  \
# 0             OH    250/500        MALE                      MD
# 1             IN    250/500        MALE                      MD
# 2             OH    100/300      FEMALE                     PhD
# 3             IL    250/500      FEMALE                     PhD
# 4             IL   500/1000        MALE               Associate
# ..           ...        ...         ...                     ...
# 995           OH   500/1000      FEMALE                 Masters
# 996           IL    100/300      FEMALE                     PhD
# 997           OH    250/500      FEMALE                 Masters
# 998           IL   500/1000        MALE               Associate
# 999           OH    250/500      FEMALE               Associate
#
#     insured_occupation insured_hobbies insured_relationship  \
# 0         craft-repair        sleeping              husband
# 1    machine-op-inspct         reading       other-relative
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_deductable  \
# count         1000.000000  1000.000000        1000.000000
# mean           203.954000    38.948000        1136.000000
# std            115.113174     9.140287         611.864673
# min              0.000000    19.000000         500.000000
# 25%            115.750000    32.000000         500.000000
# 50%            199.500000    38.000000        1000.000000
# 75%            276.250000    44.000000        2000.000000
# max            479.000000    64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06   25126.100000  -26793.700000
# std               244.167395    2.297407e+06   27872.187708   28104.096686
# min               433.330000   -1.000000e+06       0.000000 -111100.000000
# ...

# %%
for i in df.columns:
    print (i)
    print (df[i].value_counts())
    print ('='*100)
# Out:
# months_as_customer
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: months_as_customer, Length: 391, dtype: int64
# ...
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: age, dtype: int64
# ...
# policy_state
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# ...
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64
# ...
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# ...

# %% [markdown]
# Chcecking the target variable with different attributes.

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Clearly an imbalance distrubution can be seen in the target varaible. We will have to handle it with over fitting method in further stage.

# %% [markdown]
# Checking the states with target variable.

# %%
plt.figure(figsize = (14,8))
sns.countplot(df['policy_state'], hue = 'fraud_reported', data = df)
plt.show()

# %% [markdown]
# Gender with the target variables.

# %%
sns.countplot(df['insured_sex'], hue = 'fraud_reported', data = df)
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %% [markdown]
# Education level with target variable.

# %%
plt.figure(figsize = (14,8))
sns.countplot(df['insured_education_level'], hue = 'fraud_reported', data = df)
plt.show()

# %% [markdown]
# Insured Occupation with target variable.

# %%
plt.figure(figsize = (20,12))
sns.countplot(df['insured_occupation'], hue = 'fraud_reported', data = df)
plt.show()

# %% [markdown]
# Types of Incidents with target variable.

# %%
sns.countplot(df['incident_type'], hue = 'fraud_reported', data = df)
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %%
sns.countplot(df['collision_type'], hue = 'fraud_reported', data = df)
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='count'>

# %%
sns.countplot(df['incident_type'], hue = 'fraud_reported', data = df)
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %% [markdown]
# Checking the skewness, out liers & removing them.

# %%
from scipy.stats import zscore

# %%
num_col
# Out:
#      months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                   328   48               1000                1406.91
# 1                   228   42               2000                1197.22
# 2                   134   29               2000                1413.14
# 3                   256   41               2000                1415.74
# 4                   228   44               1000                1583.91
# ..                  ...  ...                ...                    ...
# 995                   3   38               1000                1310.80
# 996                 285   41               1000                1436.79
# 997                 130   34                500                1383.49
# 998                 458   62               2000                1356.92
# 999                 456   60               1000                 766.19
#
#      umbrella_limit  capital-gains  capital-loss  incident_hour_of_the_day  \
# ...

# %%
pltnum = 1
for i in num_col.columns:
    plt.figure(figsize = (24,18))
    plt.subplot(7,3,pltnum)
    sns.distplot(num_col[i])
    pltnum+=1

plt.show()

# %%
num_col.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# auto_year                     -0.048289
# policy_bind_day                0.024372
# policy_bind_month             -0.029321
# policy_bind_year               0.052511
# incident_day                   0.059111
# incident_month                 1.375894
# dtype: float64

# %%
for i in num_col.columns:
    sns.boxplot(num_col[i])
    plt.title(i)
    plt.show()

# %%
Z = np.abs(zscore(num_col))

# %%
Z
# Out:
#      months_as_customer       age  policy_deductable  policy_annual_premium  \
# 0              1.078140  0.990836           0.222383               0.616705
# 1              0.208995  0.334073           1.412784               0.242521
# 2              0.608002  1.088913           1.412784               0.642233
# 3              0.452355  0.224613           1.412784               0.652886
# 4              0.208995  0.552994           0.222383               1.341980
# ..                  ...       ...                ...                    ...
# 995            1.746582  0.103769           0.222383               0.222884
# 996            0.704407  0.224613           0.222383               0.739141
# 997            0.642767  0.541611           1.039966               0.520739
# 998            2.208028  2.523284           1.412784               0.411866
# 999            2.190645  2.304363           0.222383               2.008710
#
# ...

# %%
threshold = 3
print(np.where(Z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 4,  4,  4,  4,  4,  3,  3,  4,  4,  4,  4, 13,  4,  4,  4,  3,  6,
#         4,  4,  4], dtype=int64))

# %%
df1 = df[(Z<3).all(axis =1)]
df1
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# ...

# %%
df1.skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_deductable              0.476090
# policy_annual_premium          0.035964
# umbrella_limit                 1.801424
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_hour_of_the_day      -0.039280
# number_of_vehicles_involved    0.509725
# bodily_injuries                0.003757
# witnesses                      0.026211
# total_claim_amount            -0.593593
# injury_claim                   0.271759
# property_claim                 0.361356
# vehicle_claim                 -0.620936
# auto_year                     -0.054522
# policy_bind_day                0.028152
# policy_bind_month             -0.024643
# policy_bind_year               0.065022
# incident_day                   0.055443
# incident_month                 1.388336
# dtype: float64

# %% [markdown]
# Encoding the categorical columns.

# %%
from sklearn.preprocessing import OrdinalEncoder as oe

# %%
oe = oe()

for i in df1.columns:
    if df1[i].dtypes == 'object':
        df1[i] = oe.fit_transform(df1[i].values.reshape(-1,1))

# %%
df1
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48           2.0         1.0               1000
# 1                   228   42           1.0         1.0               2000
# 2                   134   29           2.0         0.0               2000
# 3                   256   41           0.0         1.0               2000
# 4                   228   44           0.0         2.0               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38           2.0         2.0               1000
# 996                 285   41           0.0         0.0               1000
# 997                 130   34           2.0         1.0                500
# 998                 458   62           0.0         2.0               2000
# 999                 456   60           2.0         1.0               1000
#
#      policy_annual_premium  umbrella_limit  insured_sex  \
# ...

# %%
df1.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922960     -0.007183
# age                                    0.922960  1.000000     -0.020012
# policy_state                          -0.007183 -0.020012      1.000000
# policy_csl                            -0.021855 -0.013323      0.001653
# policy_deductable                      0.031041  0.032036      0.017612
# policy_annual_premium                 -0.003814  0.005330      0.015089
# umbrella_limit                         0.018213  0.013256     -0.010921
# insured_sex                            0.059644  0.073790     -0.018002
# insured_education_level               -0.000731  0.001647     -0.027173
# insured_occupation                     0.006925  0.014798     -0.025357
# insured_hobbies                       -0.089358 -0.079099     -0.039501
# insured_relationship                   0.071492  0.076129     -0.017060
# ...

# %%
plt.figure(figsize = (30,40))
sns.heatmap(df1.corr(), annot = True)
plt.show()

# %%
df1['fraud_reported'].value_counts()
# Out:
# 0.0    740
# 1.0    240
# Name: fraud_reported, dtype: int64

# %%
sns.countplot(df1['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# We can clearly see that there is imbalance in the target variabe. We will make balanced target variable using over sampling method SMOTE.

# %%
from imblearn.over_sampling import SMOTE

# %%
x = df1.drop('fraud_reported',axis = 1)
y = df1['fraud_reported']

# %%
x
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48           2.0         1.0               1000
# 1                   228   42           1.0         1.0               2000
# 2                   134   29           2.0         0.0               2000
# 3                   256   41           0.0         1.0               2000
# 4                   228   44           0.0         2.0               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38           2.0         2.0               1000
# 996                 285   41           0.0         0.0               1000
# 997                 130   34           2.0         1.0                500
# 998                 458   62           0.0         2.0               2000
# 999                 456   60           2.0         1.0               1000
#
#      policy_annual_premium  umbrella_limit  insured_sex  \
# ...

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 995    0.0
# 996    0.0
# 997    0.0
# 998    0.0
# 999    0.0
# Name: fraud_reported, Length: 980, dtype: float64

# %%
sm = SMOTE()

xr, yr = sm.fit_resample(x,y)

# %%
xr
# Out:
#       months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                    328   48      2.000000    1.000000               1000
# 1                    228   42      1.000000    1.000000               2000
# 2                    134   29      2.000000    0.000000               2000
# 3                    256   41      0.000000    1.000000               2000
# 4                    228   44      0.000000    2.000000               1000
# ...                  ...  ...           ...         ...                ...
# 1475                 240   40      1.000000    0.078620                500
# 1476                  20   40      1.957622    2.000000               2000
# 1477                 379   50      0.538360    0.461640               1538
# 1478                 256   44      1.504476    0.752238               1628
# 1479                 205   37      1.000000    0.833019               1000
#
#       policy_annual_premium  umbrella_limit  insured_sex  \
# ...

# %%
yr
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       0.0
#        ...
# 1475    1.0
# 1476    1.0
# 1477    1.0
# 1478    1.0
# 1479    1.0
# Name: fraud_reported, Length: 1480, dtype: float64

# %%
yr.value_counts()
# Out:
# 1.0    740
# 0.0    740
# Name: fraud_reported, dtype: int64

# %%
sns.countplot(yr)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
df3 = xr

# %%
df3['fraud_reported'] = yr

# %%
df3
# Out:
#       months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                    328   48      2.000000    1.000000               1000
# 1                    228   42      1.000000    1.000000               2000
# 2                    134   29      2.000000    0.000000               2000
# 3                    256   41      0.000000    1.000000               2000
# 4                    228   44      0.000000    2.000000               1000
# ...                  ...  ...           ...         ...                ...
# 1475                 240   40      1.000000    0.078620                500
# 1476                  20   40      1.957622    2.000000               2000
# 1477                 379   50      0.538360    0.461640               1538
# 1478                 256   44      1.504476    0.752238               1628
# 1479                 205   37      1.000000    0.833019               1000
#
#       policy_annual_premium  umbrella_limit  insured_sex  \
# ...

# %%
x1 = df3.iloc[:,:-1]
y1 = df3.iloc[:,-1]

# %%
x1
# Out:
#       months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                    328   48      2.000000    1.000000               1000
# 1                    228   42      1.000000    1.000000               2000
# 2                    134   29      2.000000    0.000000               2000
# 3                    256   41      0.000000    1.000000               2000
# 4                    228   44      0.000000    2.000000               1000
# ...                  ...  ...           ...         ...                ...
# 1475                 240   40      1.000000    0.078620                500
# 1476                  20   40      1.957622    2.000000               2000
# 1477                 379   50      0.538360    0.461640               1538
# 1478                 256   44      1.504476    0.752238               1628
# 1479                 205   37      1.000000    0.833019               1000
#
#       policy_annual_premium  umbrella_limit  insured_sex  \
# ...

# %%
y1
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       0.0
#        ...
# 1475    1.0
# 1476    1.0
# 1477    1.0
# 1478    1.0
# 1479    1.0
# Name: fraud_reported, Length: 1480, dtype: float64

# %%
x1.skew()
# Out:
# months_as_customer             0.381898
# age                            0.497465
# policy_state                  -0.086346
# policy_csl                     0.143461
# policy_deductable              0.438198
# policy_annual_premium          0.024815
# umbrella_limit                 1.643160
# insured_sex                    0.091204
# insured_education_level       -0.024967
# insured_occupation            -0.037664
# insured_hobbies                0.013742
# insured_relationship           0.113465
# capital-gains                  0.488956
# capital-loss                  -0.312687
# incident_type                  0.112264
# collision_type                -0.011396
# incident_severity              0.595483
# authorities_contacted         -0.072033
# incident_state                -0.093315
# incident_city                  0.092810
# incident_hour_of_the_day      -0.047799
# number_of_vehicles_involved    0.594327
# property_damage                0.833553
# ...

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer()

for i in x1.columns:
    x1[i] = pt.fit_transform(x1[i].values.reshape(-1,1))

# %%
x1
# Out:
#       months_as_customer       age  policy_state  policy_csl  \
# 0               1.088750  1.055195      1.206989    0.213835
# 1               0.288936  0.451134     -0.005714    0.213835
# 2              -0.579386 -1.199386      1.206989   -1.307377
# 3               0.522862  0.342611     -1.367756    0.213835
# 4               0.288936  0.661061     -1.367756    1.334642
# ...                  ...       ...           ...         ...
# 1475            0.390287  0.231566     -0.005714   -1.162196
# 1476           -2.037318  0.231566      1.157636    1.334642
# 1477            1.464809  1.240760     -0.609317   -0.529968
# 1478            0.522862  0.661061      0.619538   -0.111966
# 1479            0.089606 -0.117969     -0.005714   -0.002984
#
#       policy_deductable  policy_annual_premium  umbrella_limit  insured_sex  \
# 0             -0.002520               0.649344       -0.367926     1.087982
# 1              1.301788              -0.267907        1.422377     1.087982
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

x2 = pd.DataFrame(ss.fit_transform(x1), columns = x1.columns)
x2
# Out:
#       months_as_customer       age  policy_state  policy_csl  \
# 0               1.088750  1.055195      1.206989    0.213835
# 1               0.288936  0.451134     -0.005714    0.213835
# 2              -0.579386 -1.199386      1.206989   -1.307377
# 3               0.522862  0.342611     -1.367756    0.213835
# 4               0.288936  0.661061     -1.367756    1.334642
# ...                  ...       ...           ...         ...
# 1475            0.390287  0.231566     -0.005714   -1.162196
# 1476           -2.037318  0.231566      1.157636    1.334642
# 1477            1.464809  1.240760     -0.609317   -0.529968
# 1478            0.522862  0.661061      0.619538   -0.111966
# 1479            0.089606 -0.117969     -0.005714   -0.002984
#
#       policy_deductable  policy_annual_premium  umbrella_limit  insured_sex  \
# 0             -0.002520               0.649344       -0.367926     1.087982
# 1              1.301788              -0.267907        1.422377     1.087982
# ...

# %% [markdown]
# Checking the Variance Inflation Factor.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as var

# %%
vif = pd.DataFrame()

vif['Values'] = [var(x2.values,i)for i in range(len(x2.columns))]
vif['Features'] = x2.columns

# %%
vif
# Out:
#         Values                     Features
# 0     4.998345           months_as_customer
# 1     5.018056                          age
# 2     1.046460                 policy_state
# 3     1.043109                   policy_csl
# 4     1.070869            policy_deductable
# 5     1.056204        policy_annual_premium
# 6     1.063510               umbrella_limit
# 7     1.049824                  insured_sex
# 8     1.058706      insured_education_level
# 9     1.033988           insured_occupation
# 10    1.076239              insured_hobbies
# 11    1.066977         insured_relationship
# 12    1.067907                capital-gains
# 13    1.078672                 capital-loss
# 14    8.467699                incident_type
# 15    1.081199               collision_type
# 16    1.218631            incident_severity
# 17    1.090559        authorities_contacted
# 18    1.056906               incident_state
# 19    1.049221                incident_city
# ...

# %% [markdown]
# Total Claim Amount is having the  highest values means having highest multicolinearity. Hence we will drop the column.

# %%
x2.drop('total_claim_amount', axis = 1, inplace = True)

# %%
vif1 = pd.DataFrame()

vif1['Values'] = [var(x2.values,i)for i in range(len(x2.columns))]
vif1['Features'] = x2.columns

# %%
vif1
# Out:
#       Values                     Features
# 0   4.997994           months_as_customer
# 1   5.010167                          age
# 2   1.046332                 policy_state
# 3   1.041727                   policy_csl
# 4   1.070215            policy_deductable
# 5   1.048021        policy_annual_premium
# 6   1.061867               umbrella_limit
# 7   1.047932                  insured_sex
# 8   1.058393      insured_education_level
# 9   1.031399           insured_occupation
# 10  1.072259              insured_hobbies
# 11  1.066418         insured_relationship
# 12  1.067181                capital-gains
# 13  1.077078                 capital-loss
# 14  8.464919                incident_type
# 15  1.081117               collision_type
# 16  1.182611            incident_severity
# 17  1.077799        authorities_contacted
# 18  1.054763               incident_state
# 19  1.044573                incident_city
# 20  1.108975     incident_hour_of_the_day
# ...

# %% [markdown]
# SO, now we can see that all the columns are having the vif values in normal limits hence we can proceed ahead with implemnting the data on the different models.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,AdaBoostClassifier, BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Searching for best random state.

# %%
maxac = 0
maxrs = 0

for i in range(1,200):
    lg = LogisticRegression()
    x_train,x_test,y_train,y_test = train_test_split(x2,y1, test_size = 0.30, random_state = i)
    lg.fit(x_train,y_train)
    pred = lg.predict(x_test)
    ac = accuracy_score(y_test,pred)
    if ac > maxac :
        maxac = ac
        maxrs = i
        
print('The highest accuracy score is', maxac, 'at random state', maxrs)
# Out:
# The highest accuracy score is 0.795045045045045 at random state 186

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y1, test_size = 0.30, random_state = 186)

# %%
lg.fit(x_train,y_train)
lgpred = lg.predict(x_test)
lgac = accuracy_score(y_test, lgpred)
lgcon = confusion_matrix(y_test, lgpred)
lgclass = classification_report(y_test, lgpred)

print(lgac.round(2))
print(lgcon)
print(lgclass)
# Out:
# 0.8
# [[173  46]
#  [ 45 180]]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.79      0.79       219
#          1.0       0.80      0.80      0.80       225
#
#     accuracy                           0.80       444
#    macro avg       0.80      0.79      0.79       444
# weighted avg       0.80      0.80      0.80       444

# %%
rfc = RandomForestClassifier()

rfc.fit(x_train,y_train)
rfcpred = rfc.predict(x_test)
rfcac = accuracy_score(y_test, rfcpred)
rfccon = confusion_matrix(y_test, rfcpred)
rfcclass = classification_report(y_test, rfcpred)

print(rfcac.round(2))
print(rfccon)
print(rfcclass)
# Out:
# 0.88
# [[194  25]
#  [ 30 195]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88       219
#          1.0       0.89      0.87      0.88       225
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444

# %%
etc = ExtraTreesClassifier()

etc.fit(x_train,y_train)
etcpred = etc.predict(x_test)
etcac = accuracy_score(y_test, etcpred)
etccon = confusion_matrix(y_test,etcpred)
etcclass = classification_report(y_test, etcpred)

print(etcac.round(2))
print(etccon)
print(etcclass)
# Out:
# 0.89
# [[194  25]
#  [ 24 201]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89       219
#          1.0       0.89      0.89      0.89       225
#
#     accuracy                           0.89       444
#    macro avg       0.89      0.89      0.89       444
# weighted avg       0.89      0.89      0.89       444

# %%
gbc = GradientBoostingClassifier()

gbc.fit(x_train,y_train)
gbcpred = gbc.predict(x_test)
gbcac = accuracy_score(y_test,gbcpred)
gbccon = confusion_matrix(y_test, gbcpred)
gbcclass = classification_report(y_test, gbcpred)

print(gbcac.round(2))
print(gbccon)
print(gbcclass)
# Out:
# 0.88
# [[192  27]
#  [ 25 200]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88       219
#          1.0       0.88      0.89      0.88       225
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444

# %%
adc = AdaBoostClassifier()

adc.fit(x_train,y_train)
adcpred = adc.predict(x_test)
adcac = accuracy_score(y_test, adcpred)
adccon = confusion_matrix(y_test, adcpred)
adcclass = classification_report(y_test, adcpred)

print(adcac.round(2))
print(adccon)
print(adcclass)
# Out:
# 0.88
# [[195  24]
#  [ 29 196]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88       219
#          1.0       0.89      0.87      0.88       225
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444

# %%
bc = BaggingClassifier()

bc.fit(x_train,y_train)
bcpred = bc.predict(x_test)
bcac = accuracy_score(y_test, bcpred)
bccon = confusion_matrix(y_test, bcpred)
bcclass = classification_report(y_test, bcpred)

print(bcac.round(2))
print(bccon)
print(bcclass)
# Out:
# 0.88
# [[195  24]
#  [ 31 194]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.88       219
#          1.0       0.89      0.86      0.88       225
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444

# %%
svc = SVC()

svc.fit(x_train,y_train)
svcpred = svc.predict(x_test)
svcac = accuracy_score(y_test, svcpred)
svccon = confusion_matrix(y_test, svcpred)
svcclass = classification_report(y_test, svcpred)

print(svcac.round(2))
print(svccon)
print(svcclass)
# Out:
# 0.85
# [[188  31]
#  [ 34 191]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.85       219
#          1.0       0.86      0.85      0.85       225
#
#     accuracy                           0.85       444
#    macro avg       0.85      0.85      0.85       444
# weighted avg       0.85      0.85      0.85       444

# %% [markdown]
# The Accuracy score for all the models is as follows:

# %%
print('The Accuracy score for Logistic Regression', lgac.round(2))
print('The Accuracy score for Random Forest', rfcac.round(2))
print('The Accuracy score for Extra Trees', etcac.round(2))
print('The Accuracy score for Gradient Boost', gbcac.round(2))
print('The Accuracy score for Ada Boost', adcac.round(2))
print('The Accuracy score for Bagging Classifier', bcac.round(2))
print('The Accuracy score for Support Vector', svcac.round(2))
# Out:
# The Accuracy score for Logistic Regression 0.8
# The Accuracy score for Random Forest 0.88
# The Accuracy score for Extra Trees 0.89
# The Accuracy score for Gradient Boost 0.88
# The Accuracy score for Ada Boost 0.88
# The Accuracy score for Bagging Classifier 0.88
# The Accuracy score for Support Vector 0.85

# %% [markdown]
# All the models seems to have similar Accuracy Score, Extra Trees Classifier seems to be bit better then others. We will check cross val score for all models.

# %%
cvs = cross_val_score

print('The Cross Val Score for Logistic Regression', cvs(lg,x2,y1).mean())
print('The Cross Val Score for Random Forest', cvs(rfc,x2,y1).mean())
print('The Cross Val Score for Extra Trees', cvs(etc,x2,y1).mean())
print('The Cross Val Score for Gradient Boost', cvs(gbc,x2,y1).mean())
print('The Cross Val Score for Ada Boost', cvs(adc,x2,y1).mean())
print('The Cross Val Score for Bagging Classifier', cvs(bc,x2,y1).mean())
print('The Cross Val Score for Support Vector', cvs(svc,x2,y1).mean())
# Out:
# The Cross Val Score for Logistic Regression 0.7560810810810811
# The Cross Val Score for Random Forest 0.8702702702702704
# The Cross Val Score for Extra Trees 0.8932432432432431
# The Cross Val Score for Gradient Boost 0.8587837837837838
# The Cross Val Score for Ada Boost 0.8358108108108107
# The Cross Val Score for Bagging Classifier 0.856081081081081
# The Cross Val Score for Support Vector 0.8567567567567569

# %% [markdown]
# So Cross Val score for all the models seems to be same. Hence we will consider Extra Trees as our best model. We will do hyper parameter tunning on it & save it.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'n_estimators': [100, 200, 300],
              'criterion': ['gini', 'entropy'],
              'max_features': ['auto', 'sqrt', 'log2']}

# %%
gcv = GridSearchCV(ExtraTreesClassifier(), param, cv = 5)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300]})

# %%
gcv.best_params_
# Out:
# {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 200}

# %%
fm = ExtraTreesClassifier(criterion = 'entropy', max_features = 'log2', n_estimators = 200)

# %%
fm.fit(x_train,y_train)
fmpred = fm.predict(x_test)
fmac = accuracy_score(y_test, fmpred)
fmcon = confusion_matrix(y_test, fmpred)
fmclass = classification_report(y_test, fmpred)

print(fmac.round(2))
print(fmcon)
print(fmclass)
# Out:
# 0.9
# [[196  23]
#  [ 23 202]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89       219
#          1.0       0.90      0.90      0.90       225
#
#     accuracy                           0.90       444
#    macro avg       0.90      0.90      0.90       444
# weighted avg       0.90      0.90      0.90       444

# %% [markdown]
# We have done the hyper parameter tunning of our best model & now we will save it.

# %%
from sklearn.metrics import roc_auc_score, roc_curve, plot_roc_curve

# %%
plot_roc_curve(fm, x_test, y_test)
plt.title('ROC AUC PLOT')
# Out:
# Text(0.5, 1.0, 'ROC AUC PLOT')

# %% [markdown]
# Saving the final model.

# %%
import joblib

# %%
joblib.dump(fm , 'Insurance Fraud Detection')
# Out:
# ['Insurance Fraud Detection']

# %%
md = joblib.load('Insurance Fraud Detection')

# %%
predi = md.predict(x_test)

# %%
O = np.array(y_test)

# %%
Insurance = pd.DataFrame()

Insurance['Predicted'] = predi
Insurance['Original'] = O

Insurance
# Out:
#      Predicted  Original
# 0          0.0       0.0
# 1          1.0       1.0
# 2          0.0       0.0
# 3          1.0       1.0
# 4          0.0       0.0
# ..         ...       ...
# 439        1.0       1.0
# 440        0.0       0.0
# 441        0.0       0.0
# 442        1.0       1.0
# 443        1.0       1.0
#
# [444 rows x 2 columns]

# %%
Insurance.sample(20)
# Out:
#      Predicted  Original
# 434        1.0       1.0
# 37         1.0       1.0
# 417        1.0       1.0
# 435        1.0       1.0
# 97         1.0       1.0
# 345        1.0       1.0
# 404        0.0       0.0
# 401        1.0       1.0
# 184        0.0       0.0
# 321        0.0       0.0
# 425        1.0       1.0
# 32         1.0       1.0
# 116        1.0       1.0
# 289        1.0       1.0
# 433        0.0       0.0
# 9          1.0       1.0
# 75         0.0       1.0
# 243        0.0       1.0
# 429        1.0       1.0
# 165        1.0       1.0

# %% [markdown]
# ## Conclusion:
#
# ## The Accuracy for Predecting the Fraud Against Insurance is = 90%
